# %% [markdown]
# <img src="https://sisisemail.up.edu.pe/sisisemail/_data/2021/2311/EGP/EGP.jpg" alt="Logo UP EGP" width="30%">

# %% [markdown]
# # FISCALIZACIÓN PREDICTIVA BASADA EN ALGORITMOS APLICADOS A LA SUPERVISIÓN DE TELECOMUNICACIONES

# %% [markdown]
# # Tarea Práctica: Álgebra Matricial y Computación Numérica con NumPy

# %% [markdown]
# <hr style="border: 2px solid blue;">

# %% [markdown]
# ### Datos para trabajar

# %%
import numpy as np

# 1. Producción semanal de 3 plantas industriales (filas) durante 5 días (columnas) [en unidades]
produccion = np.array([
    [150, 180, 120, 200, 160],  # Planta A
    [210, 190, 230, 240, 200],  # Planta B
    [100, 115, 130, 110, 105]   # Planta C
])

# 2. Costo operativo unitario por cada día de la semana (1D array de 5 elementos) [en USD]
costos_dia = np.array([12.5, 12.5, 15.0, 15.0, 10.0])

# 3. Matriz de precios de venta y margen por unidad para 2 productos (2x3)
precios_margen = np.array([
    [25.0, 30.0, 15.0],  # Precio de venta Producto X, Y, Z
    [10.0, 12.0,  5.0]   # Margen de ganancia Producto X, Y, Z
])

# 4. Consumo energético diario en kWh para una máquina (1D array)
energia = np.array([45.5, 50.2, 48.0, 52.1, 49.3])

print("Arrays cargados correctamente.")

# %% [markdown]
# <hr>

# %% [markdown]
# ### Nivel Básico (Creación, Indexación y Operaciones Elementales)

# %% [markdown]
# **Creación de Arrays:** Crea un array 1D llamado dias que contenga los números del 1 al 5 utilizando np.array().

# %%
# Escribe aquí tu código

# %% [markdown]
# **Indexación en 2D:** A partir de la matriz produccion, extrae el valor exacto de la producción de la Planta B en el tercer día (Miércoles).

# %%
# Escribe aquí tu código

# %% [markdown]
# **Slicing 1D:** Obtén un sub-array con las lecturas de energia correspondientes solo a los primeros 3 días de la semana.

# %%
# Escribe aquí tu código

# %% [markdown]
# **Multiplicación por escalar:** Supón que la producción del viernes (columna 4) se incrementó en un 15% debido a un turno extra. Multiplica únicamente esa última columna de produccion por $1.15$.

# %%
# Escribe aquí tu código

# %% [markdown]
# **Suma de Arrays 1D:** Si se registra un consumo extra de energía constante de $5.0\text{ kWh}$ diario representado por extra = np.array([5, 5, 5, 5, 5]), calcula el consumo total diario sumando el array energia y extra.

# %%
# Escribe aquí tu código

# %% [markdown]
# <hr>

# %% [markdown]
# ### Nivel Intermedio (Slicing 2D, Producto Hadamard y Linspace)

# %% [markdown]
# **Slicing 2D (Submatriz):** Extrae de la matriz produccion una submatriz que contenga solo el rendimiento de las Plantas A y B durante los últimos 3 días de la semana.

# %%
# Escribe aquí tu código

# %% [markdown]
# **Producto punto a punto (Hadamard):** Si los costos por unidad varían día a día según el vector costos_dia, calcula la matriz de gasto total por día y por planta multiplicando la matriz produccion por el vector costos_dia (aprovechando la propiedad de broadcasting / producto elemento a elemento).

# %%
# Escribe aquí tu código

# %% [markdown]
# **Generación de datos con linspace:** Utiliza np.linspace() para generar un array llamado x con 100 puntos de datos igualmente espaciados en el intervalo $[-2\pi, 2\pi]$ (puedes usar np.pi).

# %%
# Escribe aquí tu código

# %% [markdown]
# **Evaluación de función matemática:** Utilizando el array x generado en el punto anterior, calcula la función $y = \sin(x) + \cos(x)$ aplicando las funciones vectorizadas np.sin() y np.cos().

# %%
# Escribe aquí tu código

# %% [markdown]
# **Resta y modificación condicional:** Calcula la diferencia entre la producción diaria de la Planta B y la Planta A ($\text{Planta B} - \text{Planta A}$). Indica qué días la diferencia fue mayor a 30 unidades.

# %%
# Escribe aquí tu código

# %% [markdown]
# <hr>

# %% [markdown]
# ### Nivel Avanzado (Producto Escalar/Matricial y Modelado)

# %% [markdown]
# **Producto Escalar (Vectorial):** Dado el vector de producción de la Planta A prod_A = produccion[0] y el vector de costos_dia, calcula el costo total de producción de la semana de la Planta A utilizando el producto escalar (np.dot() o el operador @).

# %%
# Escribe aquí tu código

# %% [markdown]
# **Multiplicación Matricial 2D ($A \cdot B$):** Supón que las 3 plantas producen proporcionalmente 3 componentes distintos expresados en una matriz de composición componentes de tamaño $(3 \times 3)$. Multiplica la matriz produccion $(3 \times 5)$ por otra matriz compatible o transponla utilizando .T para calcular el volumen total por componente mediante producto matricial (@ o np.matmul()).

# %%
# Escribe aquí tu código

# %% [markdown]
# **Modelado con linspace:** Genera un array $t$ con $500$ puntos en el rango de $0$ a $10$ segundos con np.linspace(). Modela la onda de vibración de un motor utilizando la ecuación $v(t) = e^{-0.5t} \cdot \cos(2\pi t)$ empleando np.exp() y np.cos().

# %%
# Escribe aquí tu código

# %% [markdown]
# **Producto matricial para análisis de ingresos:** Si la matriz de precios_margen tiene una dimensión de $(2 \times 3)$ (filas: Precio y Margen; columnas: Productos X, Y, Z) y se tiene un volumen de ventas semanales por producto de las 3 plantas de dimensión $(3 \times 5)$, calcula la matriz total de Ingresos y Ganancias diarias ejecutando la multiplicación matricial correspondiente.

# %%
# Escribe aquí tu código

# %% [markdown]
# **Slicing y álgebra combinada:** Extrae las esquinas de la matriz produccion (primer y último día de la primera y última planta), forma un nuevo array de $2 \times 2$, y calcula el producto de su diagonal principal.

# %%
# Escribe aquí tu código

# %% [markdown]
# <hr>

# %% [markdown]
# ## Estudiante:
# Nombre de estudiante
# #### Universidad del Pacifico
