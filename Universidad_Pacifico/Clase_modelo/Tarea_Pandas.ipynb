# %% [markdown]
# <img src="https://sisisemail.up.edu.pe/sisisemail/_data/2021/2311/EGP/EGP.jpg" alt="Logo UP EGP" width="30%">

# %% [markdown]
# # FISCALIZACIÓN PREDICTIVA BASADA EN ALGORITMOS APLICADOS A LA SUPERVISIÓN DE TELECOMUNICACIONES

# %% [markdown]
# # Ejercicios

# %% [markdown]
# <hr style="border: 2px solid blue;">

# %% [markdown]
# ### Datos para trabajar

# %% [markdown]
# La tabla tiene una fila por cada producto y varias columnas.
#
# <ul>
#     <li><b>ID_Alumno</b>: Identificador único de cada estudiante.</li>
#     <li><b>Nombre</b>: Nombre y apellido del estudiante.</li>
#     <li><b>Facultad</b>: Facultad a la que pertenece el alumno (Ingeniería, Negocios, Ciencias Sociales).</li>
#     <li><b>Carrera</b>: Carrera universitaria específica que está cursando.</li>
#     <li><b>Edad</b>: Edad actual del estudiante en años.</li>
#     <li><b>Genero</b>: Género del estudiante (M = Masculino, F = Femenino).</li>
#     <li><b>Promedio</b>: Promedio académico ponderado (en escala de 0 a 20).</li>
#     <li><b>Creditos_Aprobados</b>: Cantidad total de créditos aprobados a la fecha.</li>
#     <li><b>Pension_USD</b>: Costo de la pensión mensual en dólares.</li>
#     <li><b>Beca_Vigente</b>: Estado de beca del estudiante (True = Tiene beca, False = No tiene beca).</li>
# </ul>
#
# Puedes ver el dataset completo aquí:
#
# <font size="1">
# <table style="font-size:medium; border:1px solid black; border-collapse:collapse;" border="1">
#   <tr>
#     <th>ID_Alumno</th>
#     <th>Nombre</th>
#     <th>Facultad</th>
#     <th>Carrera</th>
#     <th>Edad</th>
#     <th>Genero</th>
#     <th>Promedio</th>
#     <th>Creditos_Aprobados</th>
#     <th>Pension_USD</th>
#     <th>Beca_Vigente</th>
#   </tr>
#   <tr>
#     <td>202401</td>
#     <td>Carlos Reyes</td>
#     <td>Ingeniería</td>
#     <td>Sistemas</td>
#     <td>20</td>
#     <td>M</td>
#     <td>16.5</td>
#     <td>60</td>
#     <td>650.00</td>
#     <td>True</td>
#   </tr>
#   <tr>
#     <td>202402</td>
#     <td>Lucía Mendoza</td>
#     <td>Negocios</td>
#     <td>Marketing</td>
#     <td>22</td>
#     <td>F</td>
#     <td>14.2</td>
#     <td>85</td>
#     <td>580.00</td>
#     <td>False</td>
#   </tr>
#   <tr>
#     <td>202403</td>
#     <td>Mateo Silva</td>
#     <td>Ingeniería</td>
#     <td>Industrial</td>
#     <td>19</td>
#     <td>M</td>
#     <td>17.8</td>
#     <td>40</td>
#     <td>650.00</td>
#     <td>True</td>
#   </tr>
#   <tr>
#     <td>202404</td>
#     <td>Andrea Castro</td>
#     <td>Ciencias Sociales</td>
#     <td>Psicología</td>
#     <td>21</td>
#     <td>F</td>
#     <td>15.0</td>
#     <td>70</td>
#     <td>520.00</td>
#     <td>False</td>
#   </tr>
#   <tr>
#     <td>202405</td>
#     <td>Gabriel Torres</td>
#     <td>Negocios</td>
#     <td>Administración</td>
#     <td>23</td>
#     <td>M</td>
#     <td>11.8</td>
#     <td>90</td>
#     <td>580.00</td>
#     <td>False</td>
#   </tr>
#   <tr>
#     <td>202406</td>
#     <td>Valeria Vargas</td>
#     <td>Ingeniería</td>
#     <td>Sistemas</td>
#     <td>18</td>
#     <td>F</td>
#     <td>18.2</td>
#     <td>25</td>
#     <td>650.00</td>
#     <td>True</td>
#   </tr>
#   <tr>
#     <td>202407</td>
#     <td>Diego Morales</td>
#     <td>Ciencias Sociales</td>
#     <td>Derecho</td>
#     <td>24</td>
#     <td>M</td>
#     <td>10.5</td>
#     <td>110</td>
#     <td>520.00</td>
#     <td>False</td>
#   </tr>
#   <tr>
#     <td>202408</td>
#     <td>Camila Ríos</td>
#     <td>Negocios</td>
#     <td>Finanzas</td>
#     <td>20</td>
#     <td>F</td>
#     <td>15.9</td>
#     <td>55</td>
#     <td>580.00</td>
#     <td>True</td>
#   </tr>
#   <tr>
#     <td>202409</td>
#     <td>Jorge Benítez</td>
#     <td>Ingeniería</td>
#     <td>Industrial</td>
#     <td>22</td>
#     <td>M</td>
#     <td>13.0</td>
#     <td>75</td>
#     <td>650.00</td>
#     <td>False</td>
#   </tr>
#   <tr>
#     <td>202410</td>
#     <td>Sofia Herrera</td>
#     <td>Ciencias Sociales</td>
#     <td>Psicología</td>
#     <td>19</td>
#     <td>F</td>
#     <td>16.0</td>
#     <td>35</td>
#     <td>520.00</td>
#     <td>True</td>
#   </tr>
# </table>
# </font>

# %% [markdown]
# Puedes descargar el archivo **alumnos_universidad.csv** desde el siguiente link:
# https://github.com/JosephGarciaS/Curso_ML/tree/main/Universidad_Pacifico/Clase_modelo

# %% [markdown]
# <hr>

# %% [markdown]
# ### Nivel Básico (Conceptos fundamentales y selección

# %% [markdown]
# **1. Carga y exportación inicial:** Carga el archivo .csv desde la web en un DataFrame llamado df y muestra las primeras 5 filas.

# %%
# Escribe aquí tu código

# %% [markdown]
# **2. Slicing por columnas:** Extrae y muestra únicamente un nuevo DataFrame que contenga las columnas 'Nombre', 'Carrera' y 'Promedio'.

# %%
# Escribe aquí tu código

# %% [markdown]
# **3. Uso de .iloc:** Utiliza la función .iloc para extraer la fila del tercer alumno (índice 2) con todas sus columnas.

# %%
# Escribe aquí tu código

# %% [markdown]
# **4. Valores únicos:** Muestra la lista de las diferentes Facultades únicas registradas en la universidad utilizando la función .unique().

# %%
# Escribe aquí tu código

# %% [markdown]
# **5. Filtrado simple (>):** Filtra y muestra a todos los estudiantes cuyo 'Promedio' sea mayor a 15.0.

# %%
# Escribe aquí tu código

# %% [markdown]
# <hr>

# %% [markdown]
# ### Nivel Intermedio (Uso de .loc, condicionales múltiples y selección avanzada)

# %% [markdown]
# **1. Uso de .loc con etiquetas:** Utiliza .loc para seleccionar a las filas de los índices del 2 al 6, mostrando únicamente las columnas 'Nombre', 'Edad' y 'Promedio'.

# %%
# Escribe aquí tu código

# %% [markdown]
# **2. Filtrado condicional exacto (==):** Obtén un DataFrame que contenga únicamente a los estudiantes pertenecientes a la facultad de 'Ingeniería'.

# %%
# Escribe aquí tu código

# %% [markdown]
# **3. Valores únicos en carreras:** Muestra cuántas y cuáles son las distintas Carreras únicas que existen en el conjunto de datos.

# %%
# Escribe aquí tu código

# %% [markdown]
# **4. Filtrado combinado (< y booleanos):** Muestra a los alumnos que tengan una 'Pension_USD' menor a 600.00 y que además NO tengan beca (Beca_Vigente == False).

# %%
# Escribe aquí tu código

# %% [markdown]
# **5. Selección con .iloc específica:** Usa .iloc para obtener las últimas 3 filas del DataFrame, considerando únicamente las primeras 4 columnas (índices de columna 0 a 3).

# %% [markdown]
# <hr>

# %% [markdown]
# ### Nivel Avanzado (Modificación, filtrados complejos y exportación)

# %% [markdown]
# **1. Uso combinado de .loc con condición booleana:** Utiliza .loc para filtrar a los estudiantes que tienen 'Beca_Vigente' == True y extrae de ellos únicamente las columnas 'Nombre', 'Promedio' y 'Pension_USD'.

# %%
# Escribe aquí tu código

# %% [markdown]
# **2. Creación de columna calculada:** Crea una nueva columna llamada 'Costo_Por_Credito' que resulte de dividir la 'Pension_USD' entre los 'Creditos_Aprobados'.

# %%
# Escribe aquí tu código

# %% [markdown]
# **3. Filtro avanzado multitermino:** Encuentra a los estudiantes que tengan un 'Promedio' mayor o igual a 14.0, que tengan más de 50 créditos aprobados (Creditos_Aprobados > 50) y cuya ciudad o condición no sea crítica (por ejemplo, pertenecientes a 'Negocios' o 'Ingeniería').

# %%
# Escribe aquí tu código

# %% [markdown]
# **4. Selección de celda específica:** Utiliza la combinación de .loc o .iloc para extraer el nombre exacto del estudiante que se encuentra en la posición de la fila 5 y columna 'Nombre'.

# %%
# Escribe aquí tu código

# %% [markdown]
# **5. Filtrado final y guardado:** Filtra a todos los estudiantes en situación de riesgo académica (Promedio < 13.0) y guarda ese subconjunto de datos resultante en un nuevo archivo llamado alumnos_riesgo.csv (asegúrate de incluir index=False).

# %%
# Escribe aquí tu código

# %% [markdown]
# <hr>

# %% [markdown]
# ## Estudiante:
# Nombre de estudiante
# #### Universidad del Pacifico
